# %%
pip install korNum
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install clipboard
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install bs4
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import re
import clipboard
from korNum.chgFormat import kor2num
import os
import time
import pandas as pd
from urllib.request import urlopen
import requests
from bs4 import BeautifulSoup

# %%
def data_gagong() :
    f = open("test1.txt", 'r', encoding='utf-8' )
    text = f.read()
    #1 ,? 지우기
    pattern_comma = re.compile(r"[,]")  # 쉼표와 그 뒤에 나오는 공백 문자들을 찾는 패턴입니다.
    new_text = re.sub(pattern_comma, "", text)  # 쉼표와 그 뒤에 나오는 공백을 "와 "로 바꿉니다.
    
    pattern_question = re.compile(r"[?]") 
    new_text = re.sub(pattern_question, ".", new_text)
    
    patterns = {
        r"죠 ": "죠. ",
        r"천 사": "1004",
        r"천사": "1004",
        r"감만 사": "감만 4",
        
        
        r"이 공 구": "209",
        r"오 호": "5호",
        r"오호": "5호",
        #600~301
r"오백 구십 구": "599",
r"오백 구십 팔": "598",
r"오백 구십 칠": "597",
r"오백 구십 육": "596",
r"오백 구십 오": "595",
r"오백 구십 사": "594",
r"오백 구십 삼": "593",
r"오백 구십 이": "592",
r"오백 구십 일": "591",
r"오백 구십": "590",
r"오백 팔십 구": "589",
r"오백 팔십 팔": "588",
r"오백 팔십 칠": "587",
r"오백 팔십 육": "586",
r"오백 팔십 오": "585",
r"오백 팔십 사": "584",
r"오백 팔십 삼": "583",
r"오백 팔십 이": "582",
r"오백 팔십 일": "581",
r"오백 팔십": "580",
r"오백 칠십 구": "579",
r"오백 칠십 팔": "578",
r"오백 칠십 칠": "577",
r"오백 칠십 육": "576",
r"오백 칠십 오": "575",
r"오백 칠십 사": "574",
r"오백 칠십 삼": "573",
r"오백 칠십 이": "572",
r"오백 칠십 일": "571",
r"오백 칠십": "570",
r"오백 육십 구": "569",
r"오백 육십 팔": "568",
r"오백 육십 칠": "567",
r"오백 육십 육": "566",
r"오백 육십 오": "565",
r"오백 육십 사": "564",
r"오백 육십 삼": "563",
r"오백 육십 이": "562",
r"오백 육십 일": "561",
r"오백 육십": "560",
r"오백 오십 구": "559",
r"오백 오십 팔": "558",
r"오백 오십 칠": "557",
r"오백 오십 육": "556",
r"오백 오십 오": "555",
r"오백 오십 사": "554",
r"오백 오십 삼": "553",
r"오백 오십 이": "552",
r"오백 오십 일": "551",
r"오백 오십": "550",
r"오백 사십 구": "549",
r"오백 사십 팔": "548",
r"오백 사십 칠": "547",
r"오백 사십 육": "546",
r"오백 사십 오": "545",
r"오백 사십 사": "544",
r"오백 사십 삼": "543",
r"오백 사십 이": "542",
r"오백 사십 일": "541",
r"오백 사십": "540",
r"오백 삼십 구": "539",
r"오백 삼십 팔": "538",
r"오백 삼십 칠": "537",
r"오백 삼십 육": "536",
r"오백 삼십 오": "535",
r"오백 삼십 사": "534",
r"오백 삼십 삼": "533",
r"오백 삼십 이": "532",
r"오백 삼십 일": "531",
r"오백 삼십": "530",
r"오백 이십 구": "529",
r"오백 이십 팔": "528",
r"오백 이십 칠": "527",
r"오백 이십 육": "526",
r"오백 이십 오": "525",
r"오백 이십 사": "524",
r"오백 이십 삼": "523",
r"오백 이십 이": "522",
r"오백 이십 일": "521",
r"오백 이십": "520",
r"오백 일십 구": "519",
r"오백 일십 팔": "518",
r"오백 일십 칠": "517",
r"오백 일십 육": "516",
r"오백 일십 오": "515",
r"오백 일십 사": "514",
r"오백 일십 삼": "513",
r"오백 일십 이": "512",
r"오백 일십 일": "511",
r"오백 일십": "510",
r"사백 구십 구": "499",
r"사백 구십 팔": "498",
r"사백 구십 칠": "497",
r"사백 구십 육": "496",
r"사백 구십 오": "495",
r"사백 구십 사": "494",
r"사백 구십 삼": "493",
r"사백 구십 이": "492",
r"사백 구십 일": "491",
r"사백 구십": "490",
r"사백 팔십 구": "489",
r"사백 팔십 팔": "488",
r"사백 팔십 칠": "487",
r"사백 팔십 육": "486",
r"사백 팔십 오": "485",
r"사백 팔십 사": "484",
r"사백 팔십 삼": "483",
r"사백 팔십 이": "482",
r"사백 팔십 일": "481",
r"사백 팔십": "480",
r"사백 칠십 구": "479",
r"사백 칠십 팔": "478",
r"사백 칠십 칠": "477",
r"사백 칠십 육": "476",
r"사백 칠십 오": "475",
r"사백 칠십 사": "474",
r"사백 칠십 삼": "473",
r"사백 칠십 이": "472",
r"사백 칠십 일": "471",
r"사백 칠십": "470",
r"사백 육십 구": "469",
r"사백 육십 팔": "468",
r"사백 육십 칠": "467",
r"사백 육십 육": "466",
r"사백 육십 오": "465",
r"사백 육십 사": "464",
r"사백 육십 삼": "463",
r"사백 육십 이": "462",
r"사백 육십 일": "461",
r"사백 육십": "460",
r"사백 오십 구": "459",
r"사백 오십 팔": "458",
r"사백 오십 칠": "457",
r"사백 오십 육": "456",
r"사백 오십 오": "455",
r"사백 오십 사": "454",
r"사백 오십 삼": "453",
r"사백 오십 이": "452",
r"사백 오십 일": "451",
r"사백 오십": "450",
r"사백 사십 구": "449",
r"사백 사십 팔": "448",
r"사백 사십 칠": "447",
r"사백 사십 육": "446",
r"사백 사십 오": "445",
r"사백 사십 사": "444",
r"사백 사십 삼": "443",
r"사백 사십 이": "442",
r"사백 사십 일": "441",
r"사백 사십": "440",
r"사백 삼십 구": "439",
r"사백 삼십 팔": "438",
r"사백 삼십 칠": "437",
r"사백 삼십 육": "436",
r"사백 삼십 오": "435",
r"사백 삼십 사": "434",
r"사백 삼십 삼": "433",
r"사백 삼십 이": "432",
r"사백 삼십 일": "431",
r"사백 삼십": "430",
r"사백 이십 구": "429",
r"사백 이십 팔": "428",
r"사백 이십 칠": "427",
r"사백 이십 육": "426",
r"사백 이십 오": "425",
r"사백 이십 사": "424",
r"사백 이십 삼": "423",
r"사백 이십 이": "422",
r"사백 이십 일": "421",
r"사백 이십": "420",
r"사백 일십 구": "419",
r"사백 일십 팔": "418",
r"사백 일십 칠": "417",
r"사백 일십 육": "416",
r"사백 일십 오": "415",
r"사백 일십 사": "414",
r"사백 일십 삼": "413",
r"사백 일십 이": "412",
r"사백 일십 일": "411",
r"사백 일십": "410",
r"삼백 구십 구": "399",
r"삼백 구십 팔": "398",
r"삼백 구십 칠": "397",
r"삼백 구십 육": "396",
r"삼백 구십 오": "395",
r"삼백 구십 사": "394",
r"삼백 구십 삼": "393",
r"삼백 구십 이": "392",
r"삼백 구십 일": "391",
r"삼백 구십": "390",
r"삼백 팔십 구": "389",
r"삼백 팔십 팔": "388",
r"삼백 팔십 칠": "387",
r"삼백 팔십 육": "386",
r"삼백 팔십 오": "385",
r"삼백 팔십 사": "384",
r"삼백 팔십 삼": "383",
r"삼백 팔십 이": "382",
r"삼백 팔십 일": "381",
r"삼백 팔십": "380",
r"삼백 칠십 구": "379",
r"삼백 칠십 팔": "378",
r"삼백 칠십 칠": "377",
r"삼백 칠십 육": "376",
r"삼백 칠십 오": "375",
r"삼백 칠십 사": "374",
r"삼백 칠십 삼": "373",
r"삼백 칠십 이": "372",
r"삼백 칠십 일": "371",
r"삼백 칠십": "370",
r"삼백 육십 구": "369",
r"삼백 육십 팔": "368",
r"삼백 육십 칠": "367",
r"삼백 육십 육": "366",
r"삼백 육십 오": "365",
r"삼백 육십 사": "364",
r"삼백 육십 삼": "363",
r"삼백 육십 이": "362",
r"삼백 육십 일": "361",
r"삼백 육십": "360",
r"삼백 오십 구": "359",
r"삼백 오십 팔": "358",
r"삼백 오십 칠": "357",
r"삼백 오십 육": "356",
r"삼백 오십 오": "355",
r"삼백 오십 사": "354",
r"삼백 오십 삼": "353",
r"삼백 오십 이": "352",
r"삼백 오십 일": "351",
r"삼백 오십": "350",
r"삼백 사십 구": "349",
r"삼백 사십 팔": "348",
r"삼백 사십 칠": "347",
r"삼백 사십 육": "346",
r"삼백 사십 오": "345",
r"삼백 사십 사": "344",
r"삼백 사십 삼": "343",
r"삼백 사십 이": "342",
r"삼백 사십 일": "341",
r"삼백 사십": "340",
r"삼백 삼십 구": "339",
r"삼백 삼십 팔": "338",
r"삼백 삼십 칠": "337",
r"삼백 삼십 육": "336",
r"삼백 삼십 오": "335",
r"삼백 삼십 사": "334",
r"삼백 삼십 삼": "333",
r"삼백 삼십 이": "332",
r"삼백 삼십 일": "331",
r"삼백 삼십": "330",
r"삼백 이십 구": "329",
r"삼백 이십 팔": "328",
r"삼백 이십 칠": "327",
r"삼백 이십 육": "326",
r"삼백 이십 오": "325",
r"삼백 이십 사": "324",
r"삼백 이십 삼": "323",
r"삼백 이십 이": "322",
r"삼백 이십 일": "321",
r"삼백 이십": "320",
r"삼백 십 구": "319",
r"삼백 십 팔": "318",
r"삼백 십 칠": "317",
r"삼백 십 육": "316",
r"삼백 십 오": "315",
r"삼백 십 사": "314",
r"삼백 십 삼": "313",
r"삼백 십 이": "312",
r"삼백 십 일": "311",
r"삼백 십": "310",
        
        
        #300 ~ 50
r"이백 구십 구": "299",
r"이백 구십 팔": "298",
r"이백 구십 칠": "297",
r"이백 구십 육": "296",
r"이백 구십 오": "295",
r"이백 구십 사": "294",
r"이백 구십 삼": "293",
r"이백 구십 이": "292",
r"이백 구십 일": "291",
r"이백 구십": "290",
r"이백 팔십 구": "289",
r"이백 팔십 팔": "288",
r"이백 팔십 칠": "287",
r"이백 팔십 육": "286",
r"이백 팔십 오": "285",
r"이백 팔십 사": "284",
r"이백 팔십 삼": "283",
r"이백 팔십 이": "282",
r"이백 팔십 일": "281",
r"이백 팔십": "280",
r"이백 칠십 구": "279",
r"이백 칠십 팔": "278",
r"이백 칠십 칠": "277",
r"이백 칠십 육": "276",
r"이백 칠십 오": "275",
r"이백 칠십 사": "274",
r"이백 칠십 삼": "273",
r"이백 칠십 이": "272",
r"이백 칠십 일": "271",
r"이백 칠십": "270",
r"이백 육십 구": "269",
r"이백 육십 팔": "268",
r"이백 육십 칠": "267",
r"이백 육십 육": "266",
r"이백 육십 오": "265",
r"이백 육십 사": "264",
r"이백 육십 삼": "263",
r"이백 육십 이": "262",
r"이백 육십 일": "261",
r"이백 육십": "260",
r"이백 오십 구": "259",
r"이백 오십 팔": "258",
r"이백 오십 칠": "257",
r"이백 오십 육": "256",
r"이백 오십 오": "255",
r"이백 오십 사": "254",
r"이백 오십 삼": "253",
r"이백 오십 이": "252",
r"이백 오십 일": "251",
r"이백 오십": "250",
r"이백 사십 구": "249",
r"이백 사십 팔": "248",
r"이백 사십 칠": "247",
r"이백 사십 육": "246",
r"이백 사십 오": "245",
r"이백 사십 사": "244",
r"이백 사십 삼": "243",
r"이백 사십 이": "242",
r"이백 사십 일": "241",
r"이백 사십": "240",
r"이백 삼십 구": "239",
r"이백 삼십 팔": "238",
r"이백 삼십 칠": "237",
r"이백 삼십 육": "236",
r"이백 삼십 오": "235",
r"이백 삼십 사": "234",
r"이백 삼십 삼": "233",
r"이백 삼십 이": "232",
r"이백 삼십 일": "231",
r"이백 삼십": "230",
r"이백 이십 구": "229",
r"이백 이십 팔": "228",
r"이백 이십 칠": "227",
r"이백 이십 육": "226",
r"이백 이십 오": "225",
r"이백 이십 사": "224",
r"이백 이십 삼": "223",
r"이백 이십 이": "222",
r"이백 이십 일": "221",
r"이백 이십": "220",
r"이백 십 구": "219",
r"이백 십 팔": "218",
r"이백 십 칠": "217",
r"이백 십 육": "216",
r"이백 십 오": "215",
r"이백 십 사": "214",
r"이백 십 삼": "213",
r"이백 십 이": "212",
r"이백 십 일": "211",
r"이백 십": "210",
r"백 구십 구": "199",
r"백 구십 팔": "198",
r"백 구십 칠": "197",
r"백 구십 육": "196",
r"백 구십 오": "195",
r"백 구십 사": "194",
r"백 구십 삼": "193",
r"백 구십 이": "192",
r"백 구십 일": "191",
r"백 구십": "190",
r"백 팔십 구": "189",
r"백 팔십 팔": "188",
r"백 팔십 칠": "187",
r"백 팔십 육": "186",
r"백 팔십 오": "185",
r"백 팔십 사": "184",
r"백 팔십 삼": "183",
r"백 팔십 이": "182",
r"백 팔십 일": "181",
r"백 팔십": "180",
r"백 칠십 구": "179",
r"백 칠십 팔": "178",
r"백 칠십 칠": "177",
r"백 칠십 육": "176",
r"백 칠십 오": "175",
r"백 칠십 사": "174",
r"백 칠십 삼": "173",
r"백 칠십 이": "172",
r"백 칠십 일": "171",
r"백 칠십": "170",
r"백 육십 구": "169",
r"백 육십 팔": "168",
r"백 육십 칠": "167",
r"백 육십 육": "166",
r"백 육십 오": "165",
r"백 육십 사": "164",
r"백 육십 삼": "163",
r"백 육십 이": "162",
r"백 육십 일": "161",
r"백 육십": "160",
r"백 오십 구": "159",
r"백 오십 팔": "158",
r"백 오십 칠": "157",
r"백 오십 육": "156",
r"백 오십 오": "155",
r"백 오십 사": "154",
r"백 오십 삼": "153",
r"백 오십 이": "152",
r"백 오십 일": "151",
r"백 오십": "150",
r"백 사십 구": "149",
r"백 사십 팔": "148",
r"백 사십 칠": "147",
r"백 사십 육": "146",
r"백 사십 오": "145",
r"백 사십 사": "144",
r"백 사십 삼": "143",
r"백 사십 이": "142",
r"백 사십 일": "141",
r"백 사십": "140",
r"백 삼십 구": "139",
r"백 삼십 팔": "138",
r"백 삼십 칠": "137",
r"백 삼십 육": "136",
r"백 삼십 오": "135",
r"백 삼십 사": "134",
r"백 삼십 삼": "133",
r"백 삼십 이": "132",
r"백 삼십 일": "131",
r"백 삼십": "130",
r"백 이십 구": "129",
r"백 이십 팔": "128",
r"백 이십 칠": "127",
r"백 이십 육": "126",
r"백 이십 오": "125",
r"백 이십 사": "124",
r"백 이십 삼": "123",
r"백 이십 이": "122",
r"백 이십 일": "121",
r"백 이십": "120",
r"백 십 구": "119",
r"백 십 팔": "118",
r"백 십 칠": "117",
r"백 십 육": "116",
r"백 십 오": "115",
r"백 십 사": "114",
r"백 십 삼": "113",
r"백 십 이": "112",
r"백 십 일": "111",
r"백 십": "110",
r"구십 구": "99",
r"구십 팔": "98",
r"구십 칠": "97",
r"구십 육": "96",
r"구십 오": "95",
r"구십 사": "94",
r"구십 삼": "93",
r"구십 이": "92",
r"구십 일": "91",
r"구십": "90",
r"팔십 구": "89",
r"팔십 팔": "88",
r"팔십 칠": "87",
r"팔십 육": "86",
r"팔십 오": "85",
r"팔십 사": "84",
r"팔십 삼": "83",
r"팔십 이": "82",
r"팔십 일": "81",
r"팔십": "80",
r"칠십 구": "79",
r"칠십 팔": "78",
r"칠십 칠": "77",
r"칠십 육": "76",
r"칠십 오": "75",
r"칠십 사": "74",
r"칠십 삼": "73",
r"칠십 이": "72",
r"칠십 일": "71",
r"칠십": "70",
r"육십 구": "69",
r"육십 팔": "68",
r"육십 칠": "67",
r"육십 육": "66",
r"육십 오": "65",
r"육십 사": "64",
r"육십 삼": "63",
r"육십 이": "62",
r"육십 일": "61",
r"육십": "60",
r"오십 구": "59",
r"오십 팔": "58",
r"오십 칠": "57",
r"오십 육": "56",
r"오십 오": "55",
r"오십 사": "54",
r"오십 삼": "53",
r"오십 이": "52",
r"오십 일": "51",
r"오십": "50",
r"사십 구": "49",
r"사십 팔": "48",
r"사십 칠": "47",
r"사십 육": "46",
r"사십 오": "45",
r"사십 사": "44",
r"사십 삼": "43",
r"사십 이": "42",
r"사십 일": "41",
r"사십": "40",
r"삼십 구": "39",
r"삼십 팔": "38",
r"삼십 칠": "37",
r"삼십 육": "36",
r"삼십 오": "35",
r"삼십 사": "34",
r"삼십 삼": "33",
r"삼십 이": "32",
r"삼십 일": "31",
r"삼십": "30",
r"이십 구": "29",
r"이십 팔": "28",
r"이십 칠": "27",
r"이십 육": "26",
r"이십 오": "25",
r"이십 사": "24",
r"이십 삼": "23",
r"이십 이": "22",
r"이십 일": "21",
r"이십": "20",
r"십 구": "19",
r"십 팔": "18",
r"십 칠": "17",
r"십 육": "16",
r"십 오": "15",
r"십 사": "14",
r"십 삼": "13",
r"십 이": "12",
r"십 일": "11",


        
        #600~301 띄ㅅ어쓰기 버전 2
r"육 백": "600",
r"오 백 구십 구": "599",
r"오 백 구십 팔": "598",
r"오 백 구십 칠": "597",
r"오 백 구십 육": "596",
r"오 백 구십 오": "595",
r"오 백 구십 사": "594",
r"오 백 구십 삼": "593",
r"오 백 구십 이": "592",
r"오 백 구십 일": "591",
r"오 백 구십": "590",
r"오 백 팔십 구": "589",
r"오 백 팔십 팔": "588",
r"오 백 팔십 칠": "587",
r"오 백 팔십 육": "586",
r"오 백 팔십 오": "585",
r"오 백 팔십 사": "584",
r"오 백 팔십 삼": "583",
r"오 백 팔십 이": "582",
r"오 백 팔십 일": "581",
r"오 백 팔십": "580",
r"오 백 칠십 구": "579",
r"오 백 칠십 팔": "578",
r"오 백 칠십 칠": "577",
r"오 백 칠십 육": "576",
r"오 백 칠십 오": "575",
r"오 백 칠십 사": "574",
r"오 백 칠십 삼": "573",
r"오 백 칠십 이": "572",
r"오 백 칠십 일": "571",
r"오 백 칠십": "570",
r"오 백 육십 구": "569",
r"오 백 육십 팔": "568",
r"오 백 육십 칠": "567",
r"오 백 육십 육": "566",
r"오 백 육십 오": "565",
r"오 백 육십 사": "564",
r"오 백 육십 삼": "563",
r"오 백 육십 이": "562",
r"오 백 육십 일": "561",
r"오 백 육십": "560",
r"오 백 오십 구": "559",
r"오 백 오십 팔": "558",
r"오 백 오십 칠": "557",
r"오 백 오십 육": "556",
r"오 백 오십 오": "555",
r"오 백 오십 사": "554",
r"오 백 오십 삼": "553",
r"오 백 오십 이": "552",
r"오 백 오십 일": "551",
r"오 백 오십": "550",
r"오 백 사십 구": "549",
r"오 백 사십 팔": "548",
r"오 백 사십 칠": "547",
r"오 백 사십 육": "546",
r"오 백 사십 오": "545",
r"오 백 사십 사": "544",
r"오 백 사십 삼": "543",
r"오 백 사십 이": "542",
r"오 백 사십 일": "541",
r"오 백 사십": "540",
r"오 백 삼십 구": "539",
r"오 백 삼십 팔": "538",
r"오 백 삼십 칠": "537",
r"오 백 삼십 육": "536",
r"오 백 삼십 오": "535",
r"오 백 삼십 사": "534",
r"오 백 삼십 삼": "533",
r"오 백 삼십 이": "532",
r"오 백 삼십 일": "531",
r"오 백 삼십": "530",
r"오 백 이십 구": "529",
r"오 백 이십 팔": "528",
r"오 백 이십 칠": "527",
r"오 백 이십 육": "526",
r"오 백 이십 오": "525",
r"오 백 이십 사": "524",
r"오 백 이십 삼": "523",
r"오 백 이십 이": "522",
r"오 백 이십 일": "521",
r"오 백 이십": "520",
r"오 백 일십 구": "519",
r"오 백 일십 팔": "518",
r"오 백 일십 칠": "517",
r"오 백 일십 육": "516",
r"오 백 일십 오": "515",
r"오 백 일십 사": "514",
r"오 백 일십 삼": "513",
r"오 백 일십 이": "512",
r"오 백 일십 일": "511",
r"오 백 일십": "510",
r"오 백": "500",
r"사 백 구십 구": "499",
r"사 백 구십 팔": "498",
r"사 백 구십 칠": "497",
r"사 백 구십 육": "496",
r"사 백 구십 오": "495",
r"사 백 구십 사": "494",
r"사 백 구십 삼": "493",
r"사 백 구십 이": "492",
r"사 백 구십 일": "491",
r"사 백 구십": "490",
r"사 백 팔십 구": "489",
r"사 백 팔십 팔": "488",
r"사 백 팔십 칠": "487",
r"사 백 팔십 육": "486",
r"사 백 팔십 오": "485",
r"사 백 팔십 사": "484",
r"사 백 팔십 삼": "483",
r"사 백 팔십 이": "482",
r"사 백 팔십 일": "481",
r"사 백 팔십": "480",
r"사 백 칠십 구": "479",
r"사 백 칠십 팔": "478",
r"사 백 칠십 칠": "477",
r"사 백 칠십 육": "476",
r"사 백 칠십 오": "475",
r"사 백 칠십 사": "474",
r"사 백 칠십 삼": "473",
r"사 백 칠십 이": "472",
r"사 백 칠십 일": "471",
r"사 백 칠십": "470",
r"사 백 육십 구": "469",
r"사 백 육십 팔": "468",
r"사 백 육십 칠": "467",
r"사 백 육십 육": "466",
r"사 백 육십 오": "465",
r"사 백 육십 사": "464",
r"사 백 육십 삼": "463",
r"사 백 육십 이": "462",
r"사 백 육십 일": "461",
r"사 백 육십": "460",
r"사 백 오십 구": "459",
r"사 백 오십 팔": "458",
r"사 백 오십 칠": "457",
r"사 백 오십 육": "456",
r"사 백 오십 오": "455",
r"사 백 오십 사": "454",
r"사 백 오십 삼": "453",
r"사 백 오십 이": "452",
r"사 백 오십 일": "451",
r"사 백 오십": "450",
r"사 백 사십 구": "449",
r"사 백 사십 팔": "448",
r"사 백 사십 칠": "447",
r"사 백 사십 육": "446",
r"사 백 사십 오": "445",
r"사 백 사십 사": "444",
r"사 백 사십 삼": "443",
r"사 백 사십 이": "442",
r"사 백 사십 일": "441",
r"사 백 사십": "440",
r"사 백 삼십 구": "439",
r"사 백 삼십 팔": "438",
r"사 백 삼십 칠": "437",
r"사 백 삼십 육": "436",
r"사 백 삼십 오": "435",
r"사 백 삼십 사": "434",
r"사 백 삼십 삼": "433",
r"사 백 삼십 이": "432",
r"사 백 삼십 일": "431",
r"사 백 삼십": "430",
r"사 백 이십 구": "429",
r"사 백 이십 팔": "428",
r"사 백 이십 칠": "427",
r"사 백 이십 육": "426",
r"사 백 이십 오": "425",
r"사 백 이십 사": "424",
r"사 백 이십 삼": "423",
r"사 백 이십 이": "422",
r"사 백 이십 일": "421",
r"사 백 이십": "420",
r"사 백 일십 구": "419",
r"사 백 일십 팔": "418",
r"사 백 일십 칠": "417",
r"사 백 일십 육": "416",
r"사 백 일십 오": "415",
r"사 백 일십 사": "414",
r"사 백 일십 삼": "413",
r"사 백 일십 이": "412",
r"사 백 일십 일": "411",
r"사 백 일십": "410",


r"사 백": "400",
r"삼 백 구십 구": "399",
r"삼 백 구십 팔": "398",
r"삼 백 구십 칠": "397",
r"삼 백 구십 육": "396",
r"삼 백 구십 오": "395",
r"삼 백 구십 사": "394",
r"삼 백 구십 삼": "393",
r"삼 백 구십 이": "392",
r"삼 백 구십 일": "391",
r"삼 백 구십": "390",
r"삼 백 팔십 구": "389",
r"삼 백 팔십 팔": "388",
r"삼 백 팔십 칠": "387",
r"삼 백 팔십 육": "386",
r"삼 백 팔십 오": "385",
r"삼 백 팔십 사": "384",
r"삼 백 팔십 삼": "383",
r"삼 백 팔십 이": "382",
r"삼 백 팔십 일": "381",
r"삼 백 팔십": "380",
r"삼 백 칠십 구": "379",
r"삼 백 칠십 팔": "378",
r"삼 백 칠십 칠": "377",
r"삼 백 칠십 육": "376",
r"삼 백 칠십 오": "375",
r"삼 백 칠십 사": "374",
r"삼 백 칠십 삼": "373",
r"삼 백 칠십 이": "372",
r"삼 백 칠십 일": "371",
r"삼 백 칠십": "370",
r"삼 백 육십 구": "369",
r"삼 백 육십 팔": "368",
r"삼 백 육십 칠": "367",
r"삼 백 육십 육": "366",
r"삼 백 육십 오": "365",
r"삼 백 육십 사": "364",
r"삼 백 육십 삼": "363",
r"삼 백 육십 이": "362",
r"삼 백 육십 일": "361",
r"삼 백 육십": "360",
r"삼 백 오십 구": "359",
r"삼 백 오십 팔": "358",
r"삼 백 오십 칠": "357",
r"삼 백 오십 육": "356",
r"삼 백 오십 오": "355",
r"삼 백 오십 사": "354",
r"삼 백 오십 삼": "353",
r"삼 백 오십 이": "352",
r"삼 백 오십 일": "351",
r"삼 백 오십": "350",
r"삼 백 사십 구": "349",
r"삼 백 사십 팔": "348",
r"삼 백 사십 칠": "347",
r"삼 백 사십 육": "346",
r"삼 백 사십 오": "345",
r"삼 백 사십 사": "344",
r"삼 백 사십 삼": "343",
r"삼 백 사십 이": "342",
r"삼 백 사십 일": "341",
r"삼 백 사십": "340",
r"삼 백 삼십 구": "339",
r"삼 백 삼십 팔": "338",
r"삼 백 삼십 칠": "337",
r"삼 백 삼십 육": "336",
r"삼 백 삼십 오": "335",
r"삼 백 삼십 사": "334",
r"삼 백 삼십 삼": "333",
r"삼 백 삼십 이": "332",
r"삼 백 삼십 일": "331",
r"삼 백 삼십": "330",
r"삼 백 이십 구": "329",
r"삼 백 이십 팔": "328",
r"삼 백 이십 칠": "327",
r"삼 백 이십 육": "326",
r"삼 백 이십 오": "325",
r"삼 백 이십 사": "324",
r"삼 백 이십 삼": "323",
r"삼백 이십 이": "322",
r"삼 백 이십 일": "321",
r"삼 백 이십": "320",
r"삼백 십 구": "319",
r"삼백 십 팔": "318",
r"삼백 십 칠": "317",
r"삼백 십 육": "316",
r"삼백 십 오": "315",
r"삼백 십 사": "314",
r"삼백 십 삼": "313",
r"삼백 십 이": "312",
r"삼백 십 일": "311",
r"삼백 십": "310",

        r"삼백 구": "309",        
r"삼백 팔": "308",   
r"삼백 칠": "307",   
r"삼백 육": "306", 
r"삼백 오": "305", 
r"삼백 사": "304", 
r"삼백 삼": "303",
r"삼백 이": "302", 
r"삼백 일": "301", 
        
        #300 ~ 50
        r"삼백": "300",
r"이백 구십 구": "299",
r"이백 구십 팔": "298",
r"이백 구십 칠": "297",
r"이백 구십 육": "296",
r"이백 구십 오": "295",
r"이백 구십 사": "294",
r"이백 구십 삼": "293",
r"이백 구십 이": "292",
r"이백 구십 일": "291",
r"이백 구십": "290",
r"이백 팔십 구": "289",
r"이백 팔십 팔": "288",
r"이백 팔십 칠": "287",
r"이백 팔십 육": "286",
r"이백 팔십 오": "285",
r"이백 팔십 사": "284",
r"이백 팔십 삼": "283",
r"이백 팔십 이": "282",
r"이백 팔십 일": "281",
r"이백 팔십": "280",
r"이백 칠십 구": "279",
r"이백 칠십 팔": "278",
r"이백 칠십 칠": "277",
r"이백 칠십 육": "276",
r"이백 칠십 오": "275",
r"이백 칠십 사": "274",
r"이백 칠십 삼": "273",
r"이백 칠십 이": "272",
r"이백 칠십 일": "271",
r"이백 칠십": "270",
r"이백 육십 구": "269",
r"이백 육십 팔": "268",
r"이백 육십 칠": "267",
r"이백 육십 육": "266",
r"이백 육십 오": "265",
r"이백 육십 사": "264",
r"이백 육십 삼": "263",
r"이백 육십 이": "262",
r"이백 육십 일": "261",
r"이백 육십": "260",
r"이백 오십 구": "259",
r"이백 오십 팔": "258",
r"이백 오십 칠": "257",
r"이백 오십 육": "256",
r"이백 오십 오": "255",
r"이백 오십 사": "254",
r"이백 오십 삼": "253",
r"이백 오십 이": "252",
r"이백 오십 일": "251",
r"이백 오십": "250",
r"이백 사십 구": "249",
r"이백 사십 팔": "248",
r"이백 사십 칠": "247",
r"이백 사십 육": "246",
r"이백 사십 오": "245",
r"이백 사십 사": "244",
r"이백 사십 삼": "243",
r"이백 사십 이": "242",
r"이백 사십 일": "241",
r"이백 사십": "240",
r"이백 삼십 구": "239",
r"이백 삼십 팔": "238",
r"이백 삼십 칠": "237",
r"이백 삼십 육": "236",
r"이백 삼십 오": "235",
r"이백 삼십 사": "234",
r"이백 삼십 삼": "233",
r"이백 삼십 이": "232",
r"이백 삼십 일": "231",
r"이백 삼십": "230",
r"이백 이십 구": "229",
r"이백 이십 팔": "228",
r"이백 이십 칠": "227",
r"이백 이십 육": "226",
r"이백 이십 오": "225",
r"이백 이십 사": "224",
r"이백 이십 삼": "223",
r"이백 이십 이": "222",
r"이백 이십 일": "221",
r"이백 이십": "220",
r"이백 십 구": "219",
r"이백 십 팔": "218",
r"이백 십 칠": "217",
r"이백 십 육": "216",
r"이백 십 오": "215",
r"이백 십 사": "214",
r"이백 십 삼": "213",
r"이백 십 이": "212",
r"이백 십 일": "211",
r"이백 십": "210",
        

        
r"이백 구": "209",        
r"이백 팔": "208",   
r"이백 칠": "207",   
r"이백 육": "206", 
r"이백 오": "205", 
r"이백 사": "204", 
r"이백 삼": "203",
r"이백 이": "202", 
r"이백 일": "201", 
        
r"이백": "200",
r"백 구십 구": "199",
r"백 구십 팔": "198",
r"백 구십 칠": "197",
r"백 구십 육": "196",
r"백 구십 오": "195",
r"백 구십 사": "194",
r"백 구십 삼": "193",
r"백 구십 이": "192",
r"백 구십 일": "191",
r"백 구십": "190",
r"백 팔십 구": "189",
r"백 팔십 팔": "188",
r"백 팔십 칠": "187",
r"백 팔십 육": "186",
r"백 팔십 오": "185",
r"백 팔십 사": "184",
r"백 팔십 삼": "183",
r"백 팔십 이": "182",
r"백 팔십 일": "181",
r"백 팔십": "180",
r"백 칠십 구": "179",
r"백 칠십 팔": "178",
r"백 칠십 칠": "177",
r"백 칠십 육": "176",
r"백 칠십 오": "175",
r"백 칠십 사": "174",
r"백 칠십 삼": "173",
r"백 칠십 이": "172",
r"백 칠십 일": "171",
r"백 칠십": "170",
r"백 육십 구": "169",
r"백 육십 팔": "168",
r"백 육십 칠": "167",
r"백 육십 육": "166",
r"백 육십 오": "165",
r"백 육십 사": "164",
r"백 육십 삼": "163",
r"백 육십 이": "162",
r"백 육십 일": "161",
r"백 육십": "160",
r"백 오십 구": "159",
r"백 오십 팔": "158",
r"백 오십 칠": "157",
r"백 오십 육": "156",
r"백 오십 오": "155",
r"백 오십 사": "154",
r"백 오십 삼": "153",
r"백 오십 이": "152",
r"백 오십 일": "151",
r"백 오십": "150",
r"백 사십 구": "149",
r"백 사십 팔": "148",
r"백 사십 칠": "147",
r"백 사십 육": "146",
r"백 사십 오": "145",
r"백 사십 사": "144",
r"백 사십 삼": "143",
r"백 사십 이": "142",
r"백 사십 일": "141",
r"백 사십": "140",
r"백 삼십 구": "139",
r"백 삼십 팔": "138",
r"백 삼십 칠": "137",
r"백 삼십 육": "136",
r"백 삼십 오": "135",
r"백 삼십 사": "134",
r"백 삼십 삼": "133",
r"백 삼십 이": "132",
r"백 삼십 일": "131",
r"백 삼십": "130",
r"백 이십 구": "129",
r"백 이십 팔": "128",
r"백 이십 칠": "127",
r"백 이십 육": "126",
r"백 이십 오": "125",
r"백 이십 사": "124",
r"백 이십 삼": "123",
r"백 이십 이": "122",
r"백 이십 일": "121",
r"백 이십": "120",
r"백 십 구": "119",
r"백 십 팔": "118",
r"백 십 칠": "117",
r"백 십 육": "116",
r"백 십 오": "115",
r"백 십 사": "114",
r"백 십 삼": "113",
r"백 십 이": "112",
r"백 십 일": "111",
r"백 십": "110",
r"백 구": "109",        
r"백 팔": "108",   
r"백 칠": "107",   
r"백 육": "106", 
r"백 오": "105", 
r"백 사": "104", 
r"백 삼": "103",
r"백 이": "102", 
r"백 일": "101", 
r"백": "100",
r"구십 구": "99",
r"구십 팔": "98",
r"구십 칠": "97",
r"구십 육": "96",
r"구십 오": "95",
r"구십 사": "94",
r"구십 삼": "93",
r"구십 이": "92",
r"구십 일": "91",
r"구십": "90",
r"팔십 구": "89",
r"팔십 팔": "88",
r"팔십 칠": "87",
r"팔십 육": "86",
r"팔십 오": "85",
r"팔십 사": "84",
r"팔십 삼": "83",
r"팔십 이": "82",
r"팔십 일": "81",
r"팔십": "80",
r"칠십 구": "79",
r"칠십 팔": "78",
r"칠십 칠": "77",
r"칠십 육": "76",
r"칠십 오": "75",
r"칠십 사": "74",
r"칠십 삼": "73",
r"칠십 이": "72",
r"칠십 일": "71",
r"칠십": "70",
r"육십 구": "69",
r"육십 팔": "68",
r"육십 칠": "67",
r"육십 육": "66",
r"육십 오": "65",
r"육십 사": "64",
r"육십 삼": "63",
r"육십 이": "62",
r"육십 일": "61",
r"육십": "60",
r"오십 구": "59",
r"오십 팔": "58",
r"오십 칠": "57",
r"오십 육": "56",
r"오십 오": "55",
r"오십 사": "54",
r"오십 삼": "53",
r"오십 이": "52",
r"오십 일": "51",
r"오십": "50",
r"사십 구": "49",
r"사십 팔": "48",
r"사십 칠": "47",
r"사십 육": "46",
r"사십 오": "45",
r"사십 사": "44",
r"사십 삼": "43",
r"사십 이": "42",
r"사십 일": "41",
r"사십": "40",
r"삼십 구": "39",
r"삼십 팔": "38",
r"삼십 칠": "37",
r"삼십 육": "36",
r"삼십 오": "35",
r"삼십 사": "34",
r"삼십 삼": "33",
r"삼십 이": "32",
r"삼십 일": "31",
r"삼십": "30",
r"이십 구": "29",
r"이십 팔": "28",
r"이십 칠": "27",
r"이십 육": "26",
r"이십 오": "25",
r"이십 사": "24",
r"이십 삼": "23",
r"이십 이": "22",
r"이십 일": "21",
r"이십": "20",
r"십 구": "19",
r"십 팔": "18",
r"십 칠": "17",
r"십 육": "16",
r"십 오": "15",
r"십 사": "14",
r"십 삼": "13",
r"십 이": "12",
r"십 일": "11",
        r" 입니다": "입니다",
        r"삼명": "3명",
        r"삼호": "3호",
        r"삼 명": "3명",
        r"삼 호": "3호",
        r"일 호": "1호",
        r"일 혜민호": "1 혜민호",
        
        "열 시": "10시",
    "열한 시": "11시",
    "열두 시": "12시",
        
       
        
        
    "열시": "10시",
    "열한시": "11시",
    "열두시": "12시",
        "열 한 시": "11시",
    "열 두 시": "12시",

    "열세시": "13시",
    "열 세 시": "13시",
        "열세 시": "13시",
    "열 네 시": "14시",
        "열네 시": "14시",
        "열네시": "14시",
        
        "열다섯 시": "15시",
        "열 다섯 시": "15시",
        "열다섯시": "15시",
        "열여섯 시": "16시",
        "열 여섯 시": "16시",
        "열여섯시": "16시",
        
        "한 시": "1시",
    "두 시": "2시",
    "세 시": "3시",
    "네 시": "4시",
    "다섯 시": "5시",
    "여섯 시": "6시",
    "일곱 시": "7시",
    "여덟 시": "8시",
    "아홉 시": "9시",
        
        
    
    "한시": "1시",
    "두시": "2시",
    "세시": "3시",
    "네시": "4시",
    "다섯시": "5시",
    "여섯시": "6시",
    "일곱시": "7시",
    "여덟시": "8시",
    "아홉시": "9시",
    
        r" 에서 ": "~",
        r"이부두": "2 부두",
        r"이 부두": "2 부두",
        r"2부두": "2 부두",
        r"5물양장": "5 물양장",
        r"오물양장": "5 물양장",
        r"오 물양장": "5 물양장",
        r"오 분": "5분",
        r"오분": "5분",
        r"오 분전": "5분 전",
        r"오분 전": "5분 전",
        r"오분전": "5분 전",
         r"열하나" : "11",
    r"열둘" : "12",
    r"열셋" : "13",
    r"열넷" : "14",
        r"열두" : "12",
    r"열세" : "13",
    r"열네" : "14",
    r"열다섯" : "15",
    r"열여섯" : "16",
    r"열일곱" : "17",
    r"열여덟" : "18",
    r"열아홉" : "19",
        
         r"열 두" : "12",
    r"열 세" : "13",
    r"열 네" : "14",
        r"열 하나" : "11",
    r"열 둘" : "12",
    r"열 셋" : "13",
    r"열 넷" : "14",
    r"열 다섯" : "15",
    r"열 여섯" : "16",
    r"열 일곱" : "17",
    r"열 여덟" : "18",
    r"열 아홉" : "19",
        
        r"하나" : "1",
        r"둘" : "2",
        r"셋" : "3",
        r"넷" : "4",
        r"다섯" : "5",
        
        r"여섯": "6",
        r"일곱": "7",
        r"여덟": "8",
        r"아홉": "9",
        r"열 시": "10시",
        r"이십일": "21",
        r"이십이": "22",
        r"이십삼": "23",
        r"이십사": "24",
        
        r"이십 일": "21",
        r"이십 이": "22",
        r"이십 삼": "23",
        r"이십 사": "24",
        r"이 십 일": "21",
        r"이 십 이": "22",
        r"이 십 삼": "23",
        r"이 십 사": "24",
        r"이 십": "20",
        r"이 십 일": "21",
        r"이 십 이": "22",
        r"이 십 삼": "23",
        r"이 십 사": "24",
        r"이 십 오": "25",
        r"이 십오": "25",
        r"이십 오": "25",
        r"이십오": "25",
        
        r"삼 십 일": "31",
        r"삼십 일": "31",
        r"삼 십일": "31",
        r"삼십일": "31",
        
        r"삼 십 이": "32",
        r"삼십 이": "32",
        r"삼 십이": "32",
        r"삼십이": "32",
        
        
        r"십 일": "11",
        r"십 이": "12",
        r"십 삼": "13",
        r"십 사": "14",
        r"십 오": "15",
        r"십 육": "16",
        r"십 칠": "17",
        r"십 팔": "18",
        r"십 구": "19",
        r"십일": "11",
        r"십이": "12",
        r"십삼": "13",
        r"십사": "14",
        r"십오": "15",
        r"십육": "16",
        r"십칠": "17",
        r"십팔": "18",
        r"십구": "19",
        r"열시": "10시",
        
        
        
    
        r"니다 ": "니다. ",
        r"니다\n": "니다. ",
        r"세요 ": "세요. ",
        r"이 십": "20",
        r"이십": "20",
        
        r"삼 십": "30",
        r"삼십": "30",
        
        r"사 십": "40",
        r"사십": "40",
        
        r"오 십": "50",
        r"오십": "50",
        r"번 석": "번석",
        r"십분": "10분",
        r"십 분": "10분",
        r" 시": "시",
        r" 분": "분",
        r" 번": "번",
        r" 명": "명",
        r" 요": "요.",
        r" 요": "요",
        r" 에": "에",
        r" 고요": "고요.",
        r"고요": "고요.",
        r"죠 ": "죠. ",
        r" 호": "호",
        r" 월": "월",
        r" 일": "일",
        r" 까지": "까지",
        
        r" 도": "º",
        r" 미터": "m",
        r"미터": "m",
        
        r"오 m/s": "5m/s",
        r"오m/s": "5m/s",
        r"오 마일": "5mile",
        r"마일": "mile",
        r" 마일": "mile",
        r" mile": "mile",
        r" m/s": "m/s",
        r"퀸 메리 이 호": "퀸 메리 2호",
        r"퀸 메리 이호": "퀸 메리 2호",
        r"알파": "A",
        r"브라보": "B",
        r"찰리": "C",
        r"델타": "D",
        r"에코": "E",
        r"폭스트롯": "F",
        r"골프": "G",
        r"호텔": "H",
        r"인디아": "I",
        r"줄리엣": "J",
        r"키로": "K",
        r"리마": "L",
        r"마이크": "M",
        r"노벰버": "N",
        r"오스카": "O",
        r"파파": "P",
        r"퀘벡": "Q",
        r"로미오": "R",
        r"시에라": "S",
        r"탱고": "T",
        r"유니폼": "U",
        r"빅터": "V",
        r"위스키": "W",
        r"엑스레이": "X",
        r"양키": "Y",
        r"줄루": "Z",
        
        r"vt": "VTS",
        
         r"''": "º",
        
                r"alpha": "A",
        r"bravo": "B",
        r"charlie": "C",
        r"delta": "D",
        r"echo": "E",
        r"foxtrot": "F",
        r"golf": "G",
        r"hotel": "H",
        r"india": "I",
        r"juliett": "J",
        r"kilo": "K",
        r"lima": "L",
        r"mike": "M",
        r"november": "N",
        r"oscar": "O",
        r"papa": "P",
        r"quebec": "Q",
        r"romeo": "R",
        r"sierra": "S",
        r"tango": "T",
        r"uniform": "U",
        r"victor": "V",
        r"whiskey": "W",
        r"X-ray": "X",
        r"Xray": "X",
        r"xray": "X",
        r"yankee": "Y",
        r"zulu": "Z",
        
        r"좌현 대 좌연": "좌현 대 좌현",
        r"좌연 대 좌현": "좌현 대 좌현",
        r"좌연 대 좌연": "좌현 대 좌현",
        
         r"좌현대 좌연": "좌현 대 좌현",
        r"좌연대 좌현": "좌현 대 좌현",
        r"좌연대 좌연": "좌현 대 좌현",
        
        r"우현 대 우연": "우현 대 우현",
        r"우연 대 우현": "우현 대 우현",
        r"우연 대 우연": "우현 대 우현",
        
         r"우현대 우연": "우현 대 우현",
        r"우연대 우현": "우현 대 우현",
        r"우연대 우연": "우현 대 우현",
        
        r"수고 하십시오": "수고하십시오",
        r"요 ": "요. ",
        r"요\n": "요.\n",
        r"까\n": "까.\n",
        r"다\n": "다.\n",
        r"오\n": "오.\n",
        r"열 두시": "12시",
        r"열 두 시": "12시",
        r"열두 시": "12시",
        r"열두시": "12시",
        r"이번석": "2번석",
        r"신선대오번": "신선대 5번",
        r"신선대 오번": "신선대 5번",
        r"신선대 오 번": "신선대 5번",
         r" 포 ": "4",
         r" 투 ": "2",
         r" 쓰리 ": "3",
        r" 세븐 ": "7",
         r" 팔 ": "8",
         r" 육 ": "6",
         r" 티이유": "TEU",
         r"티이유": "TEU",
         r" 매트릭톤": "mt",
        r" 매트릭 톤": "mt",
        r"매트릭톤": "mt",
        r"매트릭 톤": "mt",
        r" 메트릭톤": "mt",
        r" 메트릭 톤": "mt",
        r"메트릭톤": "mt",
        r"메트릭 톤": "mt",
        r"이 공 칠": "207",
        r" 케이블": "cable",
        r"케이블": "cable",
        r"키로리터": "kL",
        r"키로 리터": "kL",
        r"노트": "kn",
         r" 노트": "kn",
        r"칠 혜민호": "7 혜민호",
         r"일 공 삼": "103",
         r"일 공삼": "103",
        r"일공삼": "103",
        r"일공 삼": "103",
        r"산타모니카": "산타 모니카",
        
        r"제이 제이 알 일 사 일 공 오 일": "JJR141051",
        r" 칠 ": "7",
        r"칠": "7",
        r" 삼 ": "3",
        r" 팔 ": "8",
        r"팔": "8",
        r" 오 ": "5",
        r" 사 ": "4",
        r" 삼 ": "3",
        r" 이 ": "2",
        r" 일 ": "1",
        r" 육 ": "6",
        r"육": "6",
        r" 구 ": "9",
        
         r"공 ": "0",
        r"공": "0",
         r"mps": "m/s",
        r"eta": "ETA",
        r"방파재": "방파제",
        
        
        
    }
    for pattern, replacement in patterns.items():
        pattern = re.compile(pattern)
        new_text = re.sub(pattern, replacement, new_text)
    if(new_text =="") :
        pass
    elif(new_text.strip()[-1]!='.') :
        new_text += '.'
    print(new_text)
    clipboard.copy(new_text)

# %%
def check_file_changes(filename, last_modified):
    current_modified = os.path.getmtime(filename)
    if current_modified > last_modified:
        return current_modified
    else:
        return last_modified

# %%
filename = "test1.txt"
initial_modified = os.path.getmtime(filename)

# %%
while 1 :
    now_modifed = check_file_changes(filename, initial_modified)
    if now_modifed > initial_modified :
        data_gagong()
        initial_modified = now_modifed
    time.sleep(1)
# Out:
# =제주 VTS 산타 모니카 감도 있습니까.
# 네 산타 모니카 말씀하세요.
# 네 관제구역 진입 보고 드리겠습니다. 전 출항지 진도항 승무원 11명 여객 총원 118명 승차 28대 화물 총 중량 46t 제주 방파제 ETA 15시 53분 이상입니다.
# 제주 VTS 산타 모니카입니다. 진입 보고 드리겠습니다. 전 출항지 진도 목적지 제주항 23번석입니다. 승무원 11명 여객 총 74명 차량 12대 화물 총 중량 21.1t 제주 항 방파제 ETA 15시 50분입니다.
# 1:제주 VTS 산타 모니카입니다. 진입 보고 드리겠습니다. 전 출항지 진도 목적지 제주항 23번석입니다. 승무원 11명 여객 총 74명 차량 12대 화물 총 중량 21.1t 제주항 방파제 ETA 15시 50분입니다.
# 2:감사합니다. 현재 제주항 풍향 340º에 4m/s 2 부두 380º에 3m/s입니다. 참고하십시오.
# 1:예 340º 3m/s 양지했습니다. 5mile 전 나오겠습니다.
# 아 부산 VTS 건우 천 200. 예 북항 대교 넘어서 e1 이나 그거서 줄 작업 좀 해가 사이드 차고 가 가겠습니다.
# 네 그 접안만 하면 되시는 거죠.
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /var/folders/67/n30ljkxj041gwh9b293bhytw0000gn/T/ipykernel_7606/630809461.py in <module>
#       4         data_gagong()
#       5         initial_modified = now_modifed
# ----> 6     time.sleep(1)
#
# KeyboardInterrupt:
